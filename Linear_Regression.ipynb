# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.arange(0,10,0.25)

# %%
y =x*4.5+84
plt.plot(x,y)

# %%
height = np.array([[151],[174],[138],[186],[128],[136],[179],[163],[152],[131]])
weight = np.array([63,81,56,91,47,57,76,72,62,41])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =train_test_split(height,weight, test_size =0.5,random_state =0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(height,weight)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = np.mean((y_test - y_pred)**2)
print(mse)
# Out:
# 13.347040834148519

# %%
# prompt: create a plot showing the regression line created by the regression model varaible trained

# Plot the regression line
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='red')
plt.show()
