# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x= np.arange(-5,5,0.25)
y= x*4.3+36.07
plt.plot(x,y)

# %%
def sigmoid (num):
    return 1/(1+np.exp(-num))

# %%
plt.plot(x,sigmoid(x))
