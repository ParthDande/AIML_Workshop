# %%
import pandas as pd

# %% [markdown]
# **Series**

# %%
s = pd.Series([1,2,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# s[2]#this will printe the second indexed Data

# %%
s[2]#this will printe the second indexed Data
print(s.size)
print(s.min)
print(s.max)
# Out:
# 5
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64>
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64>

# %% [markdown]
# **DataFrame**
# Multiple types of data can be stored in DataFrame

# %%
r= pd.Series([1,2,3,4,5])
n = pd.Series(['Ajay','Vijay','Sameer','Priya','Pratap'])
m = pd.Series([67.5,68.5,69.5,78.2,99.1])
df=pd.DataFrame({'Roll':r,'name':n,'marks':m})
print(df.shape)
print(df.size)
print(df.dtypes)
# Out:
# (5, 3)
# 15
# Roll       int64
# name      object
# marks    float64
# dtype: object

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# CSV- COMMA SEPERATED VALUES
# csv are used becasue they are much smaller in size compared to excels

# %%
#importing the data
df=pd.read_csv('/content/student.csv')
print(df.shape)
print(df.size)
print(df.dtypes)
print(df.columns)
# Out:
# (10, 5)
# 50
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.tail()#this give the last 5 entries in the dataframe we can get custom rows by putting value in the tail(value)
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.head()#this gives the first 5 entries in the dataset
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %% [markdown]
# **Index Based Slicing**

# %%
df.iloc[4:9,1:4]# this will give rows 4 to 9 and it will give columns from 1 to 3
df.iloc[:9,1:4]
# Out:
#       name class  marks
# 0     anil    TE  56.77
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33
# 8     amol    TE  56.75

# %%
df.iloc[1:,1:]
# Out:
#       name class  marks  age
# 1     amit    TE  59.77   21
# 2   aniket    BE  76.88   19
# 3  ajinkya    TE  69.66   20
# 4     asha    TE  63.28   20
# 5   ayesha    BE  49.55   20
# 6     amar    BE  65.34   19
# 7    amita    BE  68.33   23
# 8     amol    TE  56.75   20
# 9    anmol    BE  78.66   21

# %%
df.iloc[:,:]#if it is empty empty then it will show all data
#df.iloc[4,:4]# this will give all the rows this 4 and columns from 0 to 3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[:,1]#this will give single column
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
# to access particular row
df.iloc[[1,2,5,6],:]# this will give rows 1,2,5 and 6 and show all columns
# Out:
#    roll    name class  marks  age
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19

# %%
#specific rows and specific columns
df.iloc[[3,4,5],[1,4]]#thsi will give rows 3,4,5 and column num 1,to 4
# Out:
#       name  age
# 3  ajinkya   20
# 4     asha   20
# 5   ayesha   20

# %%
#we can get exact one row and one column.
#to get specif record from the dataFrame
df.iloc[4,3]
# Out:
# 63.28

# %% [markdown]
# Label Based Slicing

# %%
#to get all the data in column 'name'
df.loc[:,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,['name','marks']]# here we can accesses specifc rows and specific columns
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df[['name','marks','age']]#this will access all the rows for the following columns 'name' 'marks' and 'age'
# Out:
#       name  marks  age
# 0     anil  56.77   22
# 1     amit  59.77   21
# 2   aniket  76.88   19
# 3  ajinkya  69.66   20
# 4     asha  63.28   20
# 5   ayesha  49.55   20
# 6     amar  65.34   19
# 7    amita  68.33   23
# 8     amol  56.75   20
# 9    anmol  78.66   21

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.drop(5)
df.drop([4,5,6])#this will skip rows 4,5,6
df.drop('class',axis=1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
df.drop(['age','marks'],axis=1)#this will delte columns 'class' and 'roll'
# Out:
#    roll     name class
# 0     1     anil    TE
# 1     2     amit    TE
# 2     3   aniket    BE
# 3     4  ajinkya    TE
# 4     5     asha    TE
# 5     6   ayesha    BE
# 6     7     amar    BE
# 7     8    amita    BE
# 8     9     amol    TE
# 9    10    anmol    BE

# %% [markdown]
# **Data Import methods**

# %%
cols = ['roll','name','year','marks','age']
df1=pd.read_csv('/content/student1.csv',names= cols)#we ccan added columns to the csv file .
df1
# Out:
#    roll     name year  marks  age
# 0     1     anil   TE  56.77   22
# 1     2     amit   TE  59.77   21
# 2     3   aniket   BE  76.88   19
# 3     4  ajinkya   TE  69.66   20
# 4     5     asha   TE  63.28   20
# 5     6   ayesha   BE  49.55   20
# 6     7     amar   BE  65.34   19
# 7     8    amita   BE  68.33   23
# 8     9     amol   TE  56.75   20
# 9    10    anmol   BE  78.66   21

# %%
df2= pd.read_csv('/content/student3.tsv',sep = '\t')#here we need to seperte the default seperator as \t
#sep ---> stands for seperator
df2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
#we can import data set from URL
#df3.read_csv('url')

# %%
#custom column
df=pd.read_csv('/content/student.csv')
x=['M','M','M','M','F','F','M','F','M','M']
df['Gender']=x
df
# Out:
#    roll     name class  marks  age Gender
# 0     1     anil    TE  56.77   22      M
# 1     2     amit    TE  59.77   21      M
# 2     3   aniket    BE  76.88   19      M
# 3     4  ajinkya    TE  69.66   20      M
# 4     5     asha    TE  63.28   20      F
# 5     6   ayesha    BE  49.55   20      F
# 6     7     amar    BE  65.34   19      M
# 7     8    amita    BE  68.33   23      F
# 8     9     amol    TE  56.75   20      M
# 9    10    anmol    BE  78.66   21      M

# %%
df['marks']=df['marks']+0.5# this will replace the values of df['marks'] with 0.5 added to it
df
# Out:
#    roll     name class  marks  age Gender
# 0     1     anil    TE  57.27   22      M
# 1     2     amit    TE  60.27   21      M
# 2     3   aniket    BE  77.38   19      M
# 3     4  ajinkya    TE  70.16   20      M
# 4     5     asha    TE  63.78   20      F
# 5     6   ayesha    BE  50.05   20      F
# 6     7     amar    BE  65.84   19      M
# 7     8    amita    BE  68.83   23      F
# 8     9     amol    TE  57.25   20      M
# 9    10    anmol    BE  79.16   21      M

# %%
df['cgpa']=df['marks']/10+0.37
df
# Out:
#    roll     name class  marks  age Gender   cgpa
# 0     1     anil    TE  57.27   22      M  6.097
# 1     2     amit    TE  60.27   21      M  6.397
# 2     3   aniket    BE  77.38   19      M  8.108
# 3     4  ajinkya    TE  70.16   20      M  7.386
# 4     5     asha    TE  63.78   20      F  6.748
# 5     6   ayesha    BE  50.05   20      F  5.375
# 6     7     amar    BE  65.84   19      M  6.954
# 7     8    amita    BE  68.83   23      F  7.253
# 8     9     amol    TE  57.25   20      M  6.095
# 9    10    anmol    BE  79.16   21      M  8.286

# %%
#for transpose
df.T
# Out:
#             0      1       2        3      4       5      6      7      8  \
# roll        1      2       3        4      5       6      7      8      9
# name     anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class      TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks   57.27  60.27   77.38    70.16  63.78   50.05  65.84  68.83  57.25
# age        22     21      19       20     20      20     19     23     20
# Gender      M      M       M        M      F       F      M      F      M
# cgpa    6.097  6.397   8.108    7.386  6.748   5.375  6.954  7.253  6.095
#
#             9
# roll       10
# name    anmol
# class      BE
# marks   79.16
# age        21
# Gender      M
# cgpa    8.286

# %% [markdown]
# **connect**
#
# Merge , join are done on columns
# concat , Append are done on rows

# %%
ndf =pd.DataFrame({
    'roll':range(1,11),
    'gender':['M','M','M','M','F','F','M','F','M','M'],
    'cgpa':df['marks']/10+0.37
})
ndf
# Out:
#    roll gender   cgpa
# 0     1      M  6.047
# 1     2      M  6.347
# 2     3      M  8.058
# 3     4      M  7.336
# 4     5      F  6.698
# 5     6      F  5.325
# 6     7      M  6.904
# 7     8      F  7.203
# 8     9      M  6.045
# 9    10      M  8.236

# %%
#df and ndf
df= pd.read_csv('/content/student.csv')
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
ndf.columns
# Out:
# Index(['roll', 'gender', 'cgpa'], dtype='object')

# %%
df.merge(ndf,on ='roll')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.047
# 1     2     amit    TE  59.77   21      M  6.347
# 2     3   aniket    BE  76.88   19      M  8.058
# 3     4  ajinkya    TE  69.66   20      M  7.336
# 4     5     asha    TE  63.28   20      F  6.698
# 5     6   ayesha    BE  49.55   20      F  5.325
# 6     7     amar    BE  65.34   19      M  6.904
# 7     8    amita    BE  68.33   23      F  7.203
# 8     9     amol    TE  56.75   20      M  6.045
# 9    10    anmol    BE  78.66   21      M  8.236

# %%
df5 = pd.read_csv('/content/student5.csv')
df5
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
df.merge(df5,on='roll',how='right')
# Out:
#    roll   name_x class_x  marks_x  age_x   name_y class_y  marks_y  age_y
# 0     1     anil      TE    56.77     22   surbhi      TE    67.44     23
# 1     2     amit      TE    59.77     21    sujay      TE    74.12     22
# 2     3   aniket      BE    76.88     19  subhash      BE    82.44     21
# 3     4  ajinkya      TE    69.66     20   sachin      TE    59.33     21
# 4     5     asha      TE    63.28     20  shalini      TE    63.45     20

# %%
df.append([df,df5],ignore_index=True)
# Out:
# <ipython-input-157-b53b319a1064>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append([df,df5],ignore_index=True)
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1     anil    TE  56.77   22
# 11     2     amit    TE  59.77   21
# 12     3   aniket    BE  76.88   19
# 13     4  ajinkya    TE  69.66   20
# 14     5     asha    TE  63.28   20
# 15     6   ayesha    BE  49.55   20
# 16     7     amar    BE  65.34   19
# 17     8    amita    BE  68.33   23
# 18     9     amol    TE  56.75   20
# ...

# %% [markdown]
# **Methods or Fucntions**

# %%
# to find the vaerge of marks
df['marks'].mean()
# Out:
# 64.499

# %%
#to find teh max marks in the DataFrame
df['marks'].max()
# Out:
# 78.66

# %%
df['marks'].min()
# Out:
# 49.55

# %%
df['marks'].sum()
# Out:
# 644.9899999999999

# %%
df['marks'].median()
# Out:
# 64.31

# %% [markdown]
# Qualititve Data
# (cannot perform arithmatic operations with this type of data)
# * -Nominal- (cannot arrange or sort them)
# * -Ordinal ( we can arrange the data)
#
# Quantitaive
# * -descrete data
# * -Continious Values

# %%
df['class'].mode()#we can only use mode for discrete and ordinal data
# Out:
# 0    BE
# 1    TE
# Name: class, dtype: object

# %%
df['class'].value_counts()# it give the count of the frequency of  data in the dataFrame
# Out:
# TE    5
# BE    5
# Name: class, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: age, dtype: int64

# %%
df.min()#gives the minimum values of all the respective columns in the dataFrame
# Out:
# roll           1
# name     ajinkya
# class         BE
# marks      49.55
# age           19
# dtype: object

# %%
df.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-171-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# roll      5.500
# marks    64.499
# age      20.500
# dtype: float64

# %%
df.info()#this give the general summary about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# **String Operations**

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name'].str.swapcase()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %%
df['name'].str.count('a')
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# 8    1
# 9    1
# Name: name, dtype: int64

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.endswith('l')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: name, dtype: bool

# %% [markdown]
# **Grouping Operations**

# %%
gr = df.groupby('class')
gr.groups
gr.get_group('TE')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
gr.agg(sum)
# Out:
# <ipython-input-190-ee09d3dae1c2>:1: FutureWarning: The operation <built-in function sum> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   gr.agg(sum)
#        roll   marks  age
# class
# BE       34  338.76  102
# TE       21  306.23  103

# %%
gr.agg(min)
# Out:
#        roll     name  marks  age
# class
# BE        3     amar  49.55   19
# TE        1  ajinkya  56.75   20

# %%
#BooleanFiltering
df['marks']> 60#wherever the condition matches it shows True, Whereever it does not match it returns false
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask = df['marks']>60
df[mask]#this will filter out data where df['marks'] are greater than 60
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[df['marks']>60]#it will match return df['marks'] is greater than 60
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
x=df['name'].str.startswith('an')
df[x]
#or
#df[df['name'].str.startswith('an')]
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 2     3  aniket    BE  76.88   19
# 9    10   anmol    BE  78.66   21

# %%
x=df[(df['marks']>60) & (df['class']=='BE')]

# %%
##Export the data

x.to_csv('output.csv',index=False)

# %%
x.to_html('output.html',index=False)
