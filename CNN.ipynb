# %%
#note : we dont need to preprocess input data when we  use CNN
#that's the plus point of them plus we get higher accuracy compared to traditional ANN's

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D,Flatten
from keras.layers import Dense
from keras.datasets import mnist
from keras.utils import to_categorical

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape#60000 images of size 28 x 28
# Out:
# (60000, 28, 28)

# %%
#to visualize the image
plt.imshow(x_train[0],cmap='gray')
y_train[0]
# Out:
# 5

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
model = Sequential()
#input layer
model.add(Conv2D(kernel_size=(3,3),filters =16,activation = 'relu',input_shape = (28,28,1)))
model.add(MaxPool2D(pool_size =(2,2)))
model.add(Conv2D(kernel_size=(3,3),filters =32,activation = 'relu',input_shape = (28,28,1)))
model.add(MaxPool2D(pool_size =(2,2)))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))

#output layer
model.add(Dense(10,activation = 'softmax'))

# %%
model.compile(loss= 'sparse_categorical_crossentropy',optimizer='adam',metrics =['accuracy'])

# %%
model.fit(x_train,y_train,epochs = 5,batch_size = 5)
# Out:
# Epoch 1/5
# 12000/12000 [==============================] - 56s 4ms/step - loss: 0.2445 - accuracy: 0.9457
# Epoch 2/5
# 12000/12000 [==============================] - 42s 4ms/step - loss: 0.0980 - accuracy: 0.9731
# Epoch 3/5
# 12000/12000 [==============================] - 43s 4ms/step - loss: 0.0862 - accuracy: 0.9778
# Epoch 4/5
# 12000/12000 [==============================] - 41s 3ms/step - loss: 0.0784 - accuracy: 0.9811
# Epoch 5/5
# 12000/12000 [==============================] - 43s 4ms/step - loss: 0.0774 - accuracy: 0.9821

# %%
model.evaluate(x_test,y_test,batch_size = 1)
# Out:
# 10000/10000 [==============================] - 23s 2ms/step - loss: 0.0878 - accuracy: 0.9777
# [0.08777908235788345, 0.9776999950408936]

# %%
new = x_test[5205]
plt.imshow(new,cmap='gray')

# %%
new = new.reshape(1,28,28)

# %%
np.argmax(model.predict(new))
# Out:
# 1/1 [==============================] - 0s 99ms/step
# 7
